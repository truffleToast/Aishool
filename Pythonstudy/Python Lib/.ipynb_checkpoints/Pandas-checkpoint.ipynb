# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pandas 모듈 사용하기

# %%
import pandas as pd

# %% [markdown]
# ### Series 사용
# - series 생성하기

# %%
# 리스트를 이용해서 만들기
s1 = pd.Series([4,7,-5,3])
s1
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
#인덱스를 생성하어 생성
s2 = pd.Series([4,7,-5,3], index  =['d','b','a','c'])
s2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
# 딕셔너리 객체로 Series 생성
dic1 ={'a':4 ,'b':7, 'c':-5, 'd':3}
s3 =pd.Series(dic1)
# 인덱스 라벨 변경하기
s3.index=['e','f','g','h']
s3
# Out:
# e    4
# f    7
# g   -5
# h    3
# dtype: int64

# %%
#Series 값 확인
s3.values
# Out:
# array([ 4,  7, -5,  3], dtype=int64)

# %%
#Series 인덱스 확인
s3.index
# Out:
# Index(['e', 'f', 'g', 'h'], dtype='object')

# %%
#Series 데이터 타입 확인
s3.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### 실습

# %%
s2015= pd.Series({'서울':9904312, '부산' : 3448737 , '인천': 2890451 , '대구': 2466052}, dtype = 'int64')
s2015
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# dtype: int64

# %%
# Series 달아주기
s2015.name = '인구'
# Series 인덱스 이름
s2015.index.name = '도시'
s2015
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구, dtype: int64

# %% [markdown]
# * Series연산

# %%
s2015/1000000
# Out:
# 도시
# 서울    9.904312
# 부산    3.448737
# 인천    2.890451
# 대구    2.466052
# Name: 인구, dtype: float64

# %%
s2015>=3000000
# Out:
# 도시
# 서울     True
# 부산     True
# 인천    False
# 대구    False
# Name: 인구, dtype: bool

# %%
s2015 + s2015
# Out:
# 도시
# 서울    19808624
# 부산     6897474
# 인천     5780902
# 대구     4932104
# Name: 인구, dtype: int64

# %%
dic2 = {'서울':9631482, '부산': 3393191 , '인천': 2632035, '대전' : 1490158}
s2010 = pd.Series(dic2)
s2010.index.name= '도시'
s2010
# Out:
# 도시
# 서울    9631482
# 부산    3393191
# 인천    2632035
# 대전    1490158
# dtype: int64

# %%
s2015 -s2010
# Out:
# 도시
# 대구         NaN
# 대전         NaN
# 부산     55546.0
# 서울    272830.0
# 인천    258416.0
# dtype: float64

# %%
#Series 인덱싱
# 1. 숫자형 인덱스 사용
# 2, 인덱스 라벨 사용
print(s2015[1])
print(s2015['부산'])
# Series클래스를 유지한 상태로 결과 확인
print(s2015[[1]])
print()
print(s2015[[1,3,0,1]])
# Out:
# 3448737
# 3448737
# 도시
# 부산    3448737
# Name: 인구, dtype: int64
#
# 도시
# 부산    3448737
# 대구    2466052
# 서울    9904312
# 부산    3448737
# Name: 인구, dtype: int64

# %%
# Series 슬라이싱
# 1. 숫자형 인덱스 사용
# 2, 인덱스 라벨 사용
print(s2015[1:3])
print(s2015['부산':'인천']
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구, dtype: int64
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구, dtype: int64

# %%
#boolean 색인
b= [True, True, False , True]
s2015[b]
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# 대구    2466052
# Name: 인구, dtype: int64

# %%
c = s2015 > 3000000
s2015[c]
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# Name: 인구, dtype: int64

# %%
# 널값과 비교하는 함수
# seires 클래스명.innull() - > null은 true 아니면 false
# Series 클래스명.notnull() - > null 은 False
s15_10 = s2015 -s2010
s15_10.isnull()
# Out:
# 도시
# 대구     True
# 대전     True
# 부산    False
# 서울    False
# 인천    False
# dtype: bool

# %%
s15=s2015['서울': '인천']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s2015- s2010
# Out:
# 도시
# 대구         NaN
# 대전         NaN
# 부산     55546.0
# 서울    272830.0
# 인천    258416.0
# dtype: float64

# %%
incp=(s2015 - s2010) /s2010 *100
ratePopulation =incp[incp.notnull()]

# %% [markdown]
# - Series 데이터 갱신, 추가, 삭제

# %%
ratePopulation['부산'] = 1.6
ratePopulation['광주'] = 1.41
# del ratePopulation['대구']
ratePopulation
# Out:
# 도시
# 부산    1.600000
# 서울    2.832690
# 인천    9.818107
# 광주    1.410000
# dtype: float64

# %% [markdown]
# ### DataFrame 사용
# - DataFrame 생성

# %%
#리스트 이용해서 생성하기
li1 = [[9904312, 3448737, 2890451, 2466052],[9631482, 3393191, 2632035, 2431774]]
ind =['2015', '2010']
col = ['서울', '부산', '인천', '대구']
df1 =pd.DataFrame(li1, index =ind, columns =col)
df1
# Out:
#            서울       부산       인천       대구
# 2015  9904312  3448737  2890451  2466052
# 2010  9631482  3393191  2632035  2431774

# %%
# 딕셔너리 이용해서 생성하기
dic3 = {"2015": [9904312, 3448737, 2890451, 2466052], "2010": [9631482, 3393191, 2632035, 2431774]}
df2 = pd.DataFrame(dic3)
df2.index = ['부산','서울','인천','광주']
df2
# Out:
#        2015     2010
# 부산  9904312  9631482
# 서울  3448737  3393191
# 인천  2890451  2632035
# 광주  2466052  2431774

# %%
df1 = df1.transpose()

# %% [markdown]
# * 데이터 프레임 정보 확인하기

# %%
#데이터 프레임 값 확인
print(df1.values)

#데이터 프레임 인덱스 확인
print(df1.index)

#데이터 프레임 컬럼 확인
print(df1.columns)

#행/ 열 개수 가져오기
print(df1.shape)

#차원 확인
print(df1.ndim)

#전체 요소 개수
print(df1.size)
# Out:
# [[9904312 9631482]
#  [3448737 3393191]
#  [2890451 2632035]
#  [2466052 2431774]]
# Index(['서울', '부산', '인천', '대구'], dtype='object')
# Index(['2015', '2010'], dtype='object')
# (4, 2)
# 2
# 8

# %%
# 데이터 정보 일부 보기
# 위에서 보기
df1.head(3)
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191
# 인천  2890451  2632035

# %%
# 아래서 보기
df1.tail(3)
# Out:
#        2015     2010
# 부산  3448737  3393191
# 인천  2890451  2632035
# 대구  2466052  2431774

# %% [markdown]
# * 컬럼추가하기

# %%
df1['2005'] =[9762546, 3512547, 2517680, 2456016]
df1
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547
# 인천  2890451  2632035  2517680
# 대구  2466052  2431774  2456016

# %% [markdown]
# - Data Frame 색인
#
#     - 인덱싱 : 열(컬럼) 인덱싱
#     - 슬라이싱 : 행 슬라이싱
#     - boolean 색인
#     - 인덱서 활용

# %%
# 인덱싱 : 열 (컬럼) 인덱싱
print(df1['2015'])
# 데이터 프레임에서 인덱싱을 위해서는 반드시 컬럼명을 적어줘야한다.
# column명이 series의 이름이 된다.
#  - 행 인덱싱 불가능
df1[['2005']]
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 2015, dtype: int64
#        2005
# 서울  9762546
# 부산  3512547
# 인천  2517680
# 대구  2456016

# %%
# DataFrame 슬라이싱 : 행 색인
# 컬럼 슬라이싱은 불가능 합니다.
df1['서울': '부산']
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547

# %%
# 인덱스로 접근하기에 숫자로도 접근할 수 있다.
df1[:2]
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547

# %%
df1[['2015','2010']]
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191
# 인천  2890451  2632035
# 대구  2466052  2431774

# %%
df1
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547
# 인천  2890451  2632035  2517680
# 대구  2466052  2431774  2456016

# %%
df1[['2015']][1:]
# Out:
#        2015
# 부산  3448737
# 인천  2890451
# 대구  2466052

# %%
df1[1:][['2015']]
# Out:
#        2015
# 부산  3448737
# 인천  2890451
# 대구  2466052

# %%
df1[['2010','2015']][1:3]
# Out:
#        2010     2015
# 부산  3393191  3448737
# 인천  2632035  2890451

# %%
df1[1:3][['2010','2015']]
# Out:
#        2010     2015
# 부산  3393191  3448737
# 인천  2632035  2890451

# %% [markdown]
# ### loc[ ], iloc[ ] 인덱서

# %% [markdown]
# - 실제 인덱스를 사용하여 행을 가져옴
#
# > df.loc['부산']
#
# > df.loc['부산', '2010']

# %% [markdown]
# * numpy의 array인덱싱 방식으로 행을 가지고 올 때 사용
#
# > df.iloc[행]
#
# > df.iloc[행, 열]

# %%
# loc 인덱서
df1.loc[['부산']]
# Out:
#        2015     2010     2005
# 부산  3448737  3393191  3512547

# %%
df1.loc['부산':'인천','2010':'2005']
# Out:
#        2010     2005
# 부산  3393191  3512547
# 인천  2632035  2517680

# %%
df1.iloc[1:3, 1:]
# Out:
#        2010     2005
# 부산  3393191  3512547
# 인천  2632035  2517680

# %%
df1
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547
# 인천  2890451  2632035  2517680
# 대구  2466052  2431774  2456016

# %% [markdown]
# ###  boolean으로 색인

# %%
# boolean 색인

li2 = [True,True, False ,False]
df1[li2]
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547

# %%
li3= df1['2010'] >2500000
df1[['2010']][li3]
# Out:
#        2010
# 서울  9631482
# 부산  3393191
# 인천  2632035

# %%
df1.loc[li3, '2010':'2005']
# Out:
#        2010     2005
# 서울  9631482  9762546
# 부산  3393191  3512547
# 인천  2632035  2517680

# %%
# df1.iloc[li3]
# iloc는 boolean 색인이 불가능 하다.
li2 = [True, True, False, False]

df1[li2]
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547

# %% [markdown]
# ### population 실습

# %%
population_number= pd.read_csv('population_number.csv' , encoding ='euc-kr' ,index_col ='도시')

# %%
population_number
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
population_number[['2015']].value_counts()
# Out:
# 2015
# 2466052    1
# 2890451    1
# 3448737    1
# 9904312    1
# dtype: int64

# %%
population_number[['2010']].value_counts()
# Out:
# 2010
# 2431774.0    1
# 2632035.0    1
# 9631482.0    1
# dtype: int64

# %%
population_number
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# 정렬 (sort)
# sort_index : 인덱스 값을 기준으로 정렬
# sort_values : 데이터 값을 기준으로 정렬

# %%
# 오름차순이 기본
# 내림차순 변경 : ascending = False
population_number.sort_index()
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 부산  경상권  3448737        NaN        NaN  3655437
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 인천  수도권  2890451  2632035.0        NaN  2466338

# %%
population_number.sort_index(ascending = False)
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# 오름차순 values
population_number['2010'].sort_values()
# Out:
# 도시
# 대구    2431774.0
# 인천    2632035.0
# 서울    9631482.0
# 부산          NaN
# Name: 2010, dtype: float64

# %%
population_number['2010'].sort_values(ascending = False)
# Out:
# 도시
# 서울    9631482.0
# 인천    2632035.0
# 대구    2431774.0
# 부산          NaN
# Name: 2010, dtype: float64

# %%
population_number.sort_values(by = '2010')
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437

# %%
population_number.sort_values(by = '2010',ascending = False)
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 부산  경상권  3448737        NaN        NaN  3655437

# %%
# '지역' 과 '2010'을 가지고 정렬
population_number.sort_values(by = ['지역', '2010'])
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972

# %% [markdown]
# ### 스코어 실습

# %%
score =pd.read_csv("score.csv", encoding = 'cp949', index_col='과목')
score
# Out:
#      1반  2반  3반  4반
# 과목
# 파이썬  45  44  73  39
# DB   76  92  45  69
# 자바   47  92  45  69
# 크롤링  92  81  85  40
# Web  11  79  47  26

# %%
# axis = 0 일때는 반별 합계(열 기준으로)
score.sum()
# Out:
# 1반    271
# 2반    388
# 3반    295
# 4반    243
# dtype: int64

# %%
# axis =1 일때는 과목별 합계(행 기준)
score.sum(axis=1).sort_values(ascending = False)
# Out:
# 과목
# 크롤링    298
# DB     282
# 자바     253
# 파이썬    201
# Web    163
# dtype: int64

# %%
# 학급별 총합
score.sum(axis = 0).sort_values(ascending = False)
# Out:
# 2반    388
# 3반    295
# 1반    271
# 4반    243
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 합계 컬럼 생성
#1. 과목별 총합 값 구하기
#2. 컬럼 생성

# %%
hap=score.sum(axis=1)

# %%
score['합계'] = hap

# %%
score
# Out:
#      1반  2반  3반  4반   합계
# 과목
# 파이썬  45  44  73  39  201
# DB   76  92  45  69  282
# 자바   47  92  45  69  253
# 크롤링  92  81  85  40  298
# Web  11  79  47  26  163

# %%
#2 . 컬럼생성
score['합계'] =score.loc[: ,'1반':'4반'].sum(axis =1)

# %%
score
# Out:
#      1반  2반  3반  4반   합계
# 과목
# 파이썬  45  44  73  39  201
# DB   76  92  45  69  282
# 자바   47  92  45  69  253
# 크롤링  92  81  85  40  298
# Web  11  79  47  26  163

# %%
score['평균'] =score.loc[:,'1반':'4반'].mean(axis=1)
score
# Out:
#      1반  2반  3반  4반   합계     평균
# 과목
# 파이썬  45  44  73  39  201  50.25
# DB   76  92  45  69  282  70.50
# 자바   47  92  45  69  253  63.25
# 크롤링  92  81  85  40  298  74.50
# Web  11  79  47  26  163  40.75

# %%
# 반평균 데이터 생성
#1. 반평균 값 구하기
#2.  1을 이용해 반평균 삽입
classmean= score.loc[:,'1반':'평균'].mean(axis=0)
classmean
# Out:
# 1반     54.20
# 2반     77.60
# 3반     59.00
# 4반     48.60
# 합계    239.40
# 평균     59.85
# dtype: float64

# %%
score.loc['반평균']=classmean

# %%
score
# Out:
#        1반    2반    3반    4반     합계     평균
# 과목
# 파이썬  45.0  44.0  73.0  39.0  201.0  50.25
# DB   76.0  92.0  45.0  69.0  282.0  70.50
# 자바   47.0  92.0  45.0  69.0  253.0  63.25
# 크롤링  92.0  81.0  85.0  40.0  298.0  74.50
# Web  11.0  79.0  47.0  26.0  163.0  40.75
# 반평균  54.2  77.6  59.0  48.6  239.4  59.85

# %%
# 과목별 최대값과 최소값의 차이

# %%
max_score =score.max(axis=1)
min_score =score.min(axis=1)

# %%
score.loc[:'Web', '1반':'4반']
# Out:
#        1반    2반    3반    4반
# 과목
# 파이썬  45.0  44.0  73.0  39.0
# DB   76.0  92.0  45.0  69.0
# 자바   47.0  92.0  45.0  69.0
# 크롤링  92.0  81.0  85.0  40.0
# Web  11.0  79.0  47.0  26.0

# %%
mas=score.loc[:'Web', '1반':'4반'].max(axis=1)
mas
# Out:
# 과목
# 파이썬    73.0
# DB     92.0
# 자바     92.0
# 크롤링    92.0
# Web    79.0
# dtype: float64

# %%
mis=score.loc[:'Web', '1반':'4반'].min(axis=1)
mis
# Out:
# 과목
# 파이썬    39.0
# DB     45.0
# 자바     45.0
# 크롤링    40.0
# Web    11.0
# dtype: float64

# %%
mas-mis
# Out:
# 과목
# 파이썬    34.0
# DB     47.0
# 자바     47.0
# 크롤링    52.0
# Web    68.0
# dtype: float64

# %%
#apply 함수 적용
# 행 혹은 열단위로 복잡한 데이터 프레임을 처리할 때 사용

# %%
# 함수 정의
# 과목별 max 와 min 점수 차이 구하기
def max_min(x):
    return x.max()-x.min()

# %%
score.loc[:'Web', '1반':'4반'].apply(max_min, axis =1)
# Out:
# 과목
# 파이썬    34.0
# DB     47.0
# 자바     47.0
# 크롤링    52.0
# Web    68.0
# dtype: float64

# %% [markdown]
# ### 카테고리 생성하기
# * 데이터를 구간별로 구분하기!

# %%
ages = [0,2,10,35,6,112,1,50,9,10,18,1,521,5,23,60,40,1,251,1,21,3,4,5,2,61,60,2,12,80,90,91]
bins = [0,5,25,35,50,100,250, 600] # 구간 labels 변수에 넣기
labels= ['미취학아동','학생','백수', '장년', '노인', '장수','미라'] # 구간의 이름
# 1~5 까지 미취학 아동, 6~ 24까지 학생 26~35 : 백수 36~ 50 까지 장년, 51~100 까지 노인 , 101~250 장수 , 251~ 미라
cats = pd.cut(ages, bins, labels =labels)

# %%
cats
# Out:
# [NaN, '미취학아동', '학생', '백수', '학생', ..., '미취학아동', '학생', '노인', '노인', '노인']
# Length: 32
# Categories (7, object): ['미취학아동' < '학생' < '백수' < '장년' < '노인' < '장수' < '미라']

# %%
cats.value_counts
# Out:
# <bound method Categorical.value_counts of [NaN, '미취학아동', '학생', '백수', '학생', ..., '미취학아동', '학생', '노인', '노인', '노인']
# Length: 32
# Categories (7, object): ['미취학아동' < '학생' < '백수' < '장년' < '노인' < '장수' < '미라']>

# %%
age =pd.DataFrame(ages, columns =['나이'])
age
# Out:
#      나이
# 0     0
# 1     2
# 2    10
# 3    35
# 4     6
# 5   112
# 6     1
# 7    50
# 8     9
# 9    10
# 10   18
# 11    1
# 12  521
# 13    5
# 14   23
# 15   60
# 16   40
# 17    1
# 18  251
# 19    1
# 20   21
# 21    3
# 22    4
# 23    5
# 24    2
# 25   61
# 26   60
# 27    2
# 28   12
# 29   80
# 30   90
# 31   91

# %%
age['연령대']=cats

# %%
age
# Out:
#      나이    연령대
# 0     0    NaN
# 1     2  미취학아동
# 2    10     학생
# 3    35     백수
# 4     6     학생
# 5   112     장수
# 6     1  미취학아동
# 7    50     장년
# 8     9     학생
# 9    10     학생
# 10   18     학생
# 11    1  미취학아동
# 12  521     미라
# 13    5  미취학아동
# 14   23     학생
# 15   60     노인
# 16   40     장년
# 17    1  미취학아동
# 18  251     미라
# 19    1  미취학아동
# 20   21     학생
# 21    3  미취학아동
# 22    4  미취학아동
# 23    5  미취학아동
# 24    2  미취학아동
# 25   61     노인
# 26   60     노인
# 27    2  미취학아동
# 28   12     학생
# 29   80     노인
# 30   90     노인
# 31   91     노인

# %% [markdown]
# # 데이터 프레임 병합
# * merge
# * concat

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'a':['a0','a1','a2','a3'],
                   'b':['b0','b1','b2','b3'],
                   'c':['c0','c1','c2','c3']},
                  index = [0,1,2,3])

df2 = pd.DataFrame({'a':['a2','a3','a4','a5'],
                   'b':['b2','b3','b4','b5'],
                   'c':['c2','c3','c4','c5'],
                   'd':['d2','d3','d4','d5']},
                   index = [2,3,4,5])

df3 = pd.DataFrame({'a':['a3','a4','a5','a6'],
                   'b':['b3','b4','b5','b6'],
                   'c':['c3','c4','c5','c6'],
                   'd':['d3','d4','d5','d6']},
                   index = [3,4,5,6])

# %%
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
df3
# Out:
#     a   b   c   d
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6

# %%
# DataFrame 간 병합
resultDf1 = pd.concat([df1,df2])
resultDf1
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %%
# 기존 인덱스를 무시하고 새로운 인덱스를 부여
resultDf2 = pd.concat([df1,df2,df3], ignore_index=True)
resultDf2
# Out:
#      a   b   c    d
# 0   a0  b0  c0  NaN
# 1   a1  b1  c1  NaN
# 2   a2  b2  c2  NaN
# 3   a3  b3  c3  NaN
# 4   a2  b2  c2   d2
# 5   a3  b3  c3   d3
# 6   a4  b4  c4   d4
# 7   a5  b5  c5   d5
# 8   a3  b3  c3   d3
# 9   a4  b4  c4   d4
# 10  a5  b5  c5   d5
# 11  a6  b6  c6   d6

# %%
#행(인덱스 라벨)을 기준으로 병합
resultDf3 =pd.concat([df1,df2], axis =1)
resultDf3
# Out:
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# inner join
resultDf4 = pd.concat([df1,df2,df3], axis=1, join='inner')
resultDf4
# Out:
#     a   b   c   a   b   c   d   a   b   c   d
# 3  a3  b3  c3  a3  b3  c3  d3  a3  b3  c3  d3

# %%
#Series간 병합
sr1 = pd.Series(['e0','e1','e2','e3'], name = 'e')
sr2 = pd.Series(['f0','f1','f2'], name = 'f')
sr3 = pd.Series(['g0','g1','g2','g3'], name = 'g')

# %%
resultDf5 =pd.concat([sr1,sr2], axis=1)
resultDf5
# 일치하지 않는 데이터에는 nan이 출력.
# Out:
#     e    f
# 0  e0   f0
# 1  e1   f1
# 2  e2   f2
# 3  e3  NaN

# %%
#Series와 DataFrame 병합
sr4 = pd.Series(['h0','h1','h2','h3'], name = 'h', index = [1,3,4,5])
sr4
# Out:
# 1    h0
# 3    h1
# 4    h2
# 5    h3
# Name: h, dtype: object

# %%
resultDf6 =pd.concat([df2,sr4], axis=1)
resultDf6
# Out:
#      a    b    c    d    h
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3   h1
# 4   a4   b4   c4   d4   h2
# 5   a5   b5   c5   d5   h3
# 1  NaN  NaN  NaN  NaN   h0

# %%
dic1 = {'key' : ['K0','K2','K3','K4'], 'A' : ['A0','A1','A2','A3'], 'B' : ['B0','B1','B2','B3']}
df4 = pd.DataFrame(dic1)

# %%
dic2 = {'key' : ['K0','K1','K2','K3'], 'C' : ['C0','C1','C2','C3'], 'D' : ['D0','D1','D2','D3']}
df5 = pd.DataFrame(dic2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sr4 = pd.Series(['h0','h1','h2','h3'], name = 'h', index = [1,3,4,5])

# %%
#'key'컬럼을 이용해서 merge.
resultDf7 = pd.merge(df4, df5,on = 'key')
resultDf7
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A1  B1  C2  D2
# 2  K3  A2  B2  C3  D3

# %%
resultDf8 = pd.merge(df4, df5,on = 'key',how='outer')
resultDf8
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K2   A1   B1   C2   D2
# 2  K3   A2   B2   C3   D3
# 3  K4   A3   B3  NaN  NaN
# 4  K1  NaN  NaN   C1   D1

# %%
resultDf9 = pd.merge(df4, df5,on = 'key',how='left')
resultDf9
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K2  A1  B1   C2   D2
# 2  K3  A2  B2   C3   D3
# 3  K4  A3  B3  NaN  NaN

# %%
resultDf10=pd.merge(df4, df5 , on ='key' , how ='right')
resultDf10
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A1   B1  C2  D2
# 3  K3   A2   B2  C3  D3
