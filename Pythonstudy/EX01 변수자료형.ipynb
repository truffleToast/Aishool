# %%
1+2
# Out:
# 3

# %% [markdown]
# ## Jupyter notebook 사용방법
# ### ● 단축키
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
num1=13
print(num1)
num2=5.8
print(num2)
num1 = 10.5
print(num1)
# Out:
# 13
# 5.8
# 10.5

# %%
print(num1)
# Out:
# 10.5

# %%
str1='Funny Python'
str2="Easy Python"
print(str1)
print(str2)
num1='Kimmihee'
print(num1)
# Out:
# Funny Python
# Easy Python
# Kimmihee

# %% [markdown]
# ## \(역슬래시)
# ![image.png](attachment:image.png)

# %%
s1='she\'s gone'
print(s1)
# Out:
# she's gone

# %%
s2="she's gone"
print(s2)
# Out:
# she's gone

# %%
# 여러줄인 문자열을 변수에 대입
s3= "자세히 보아야 예쁘다.\n오래 보아야 사랑스럽다.\n너도 그렇다."
print(s3)
s4="""자세히 보아야 예쁘다.
오래 보아야 사랑스럽다.
너도 그렇다."""
print(s4)
# Out:
# 자세히 보아야 예쁘다.
# 오래 보아야 사랑스럽다.
# 너도 그렇다.
# 자세히 보아야 예쁘다.
# 오래 보아야 사랑스럽다.
# 너도 그렇다.

# %% [markdown]
# ## 인덱싱과 슬라이싱
# #### ● 인덱싱 - 무언가를 '가리킨다'는 의미
#
# ### 슬라이싱
# #### ● 무엇인가를 '잘라낸다'는 의미

# %%
s= "My name is MH"

# %%
#인덱싱
print(s[3])
print(s[-1])
# Out:
# n
# H

# %%
#슬라이싱
# 변수명[0~1] ->  변수명 [0:2]
## 시작 인덱스가 0이거나 끝나는 경우(-1)일 때 생략할 수 있다.
print(s[0:2])
print(s[:7])
print(s[8:])
# Out:
# My
# My name
# is MH

# %%
#문자열 안에 특정 값을 바꿔야 할 경우
month= 7
day=3
# 문자열과 숫자열 데이터는 더하기 연산이 불가
# s= '오늘은' + month+ '월 ' +day+ '일입니다.'
#print(s)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# 문자열 s만들기
s='오늘은 %d월 %d일 입니다.' %(month, day)
print(s)
# Out:
# 오늘은 7월 3일 입니다.

# %%
# format 함수를 이용한 포매팅
s= '오늘은 {}월 {}일 입니다.'.format(month, day)
print(s)
# Out:
# 오늘은 7월 3일 입니다.

# %%
# f문자열 
s= f"오늘은 {month}월 {day}일 입니다."
print(s)
# Out:
# 오늘은 7월 3일 입니다.

# %%
x=100
y=200
sum2=x+y
s1='{}와 {}의 합은 {}입니다.'.format(x,y,sum2)
print(s1)
print('%d와 %d의 합은 %d입니다.'%(x, y, sum2))
s2=f'{x}와 {y}의 합은 {sum2}입니다.'
print(s2)
# Out:
# 100와 200의 합은 300입니다.
# 100와 200의 합은 300입니다.
# 100와 200의 합은 300입니다.

# %% [markdown]
# ## 문자열 관련함수
# ![image.png](attachment:image.png)

# %%
##문다 개수 세기
s='My name is MH'
print(s.count('i'))
# Out:
# 1

# %%
# 위치 알려주기
#문자열.find(데이터): 찾는 문자가 존재하지 않을 경우 -1을 반환
# 문자열.index(데이터): 찾는 문자가 존재하지 않을 경우 에러
print(s.find('z'))
print(s.index('e'))
# Out:
# -1
# 6

# %% [markdown]
# # join과 split을 배워보자
# ## 문자열 삽입

# %%
#'문자'.join(문자열)
" ".join(s)
# Out:
# 'M y   n a m e   i s   M H'

# %%
# 문자열 나누기
#문자열.split(구분문자)
s.split() # space나 tab이나 enter를 기준으로 나누어줌
# Out:
# ['My', 'name', 'is', 'MH']

# %%
s4="안-녕-하-세-요"

# %%
#replace문
